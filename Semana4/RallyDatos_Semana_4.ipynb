# %% [markdown]
# # Rally de Datos GTO
# ## _Semana 4_: Deporte

# %%
# Se importan las librerías para el análisis de datos
import pandas as pd
import numpy as np

# Librerías para graficar
import plotly
import plotly.express as px
import plotly.graph_objects as go

# Para hacer lectura de archivos json
from urllib.request import urlopen
import json

# Para usar el algoritmo de clustering de k-means
from sklearn.cluster import KMeans

# Se define la paleta de colores de Dataket 8)
colors = ["#264653", "#2a9d8f", "#e9C46a", "#F4A261", "#E76F51"]

# %% [markdown]
# ## Lectura de Datasets

# %%
# Se define el url donde se encuentra el archivo (en el repositorio de Github)
url_inversion = "https://github.com/GOLF-fisica/Dataket/raw/main/Semana4/Inversion_1T_Qs_por_municipio.csv"

# Se lee el archivo
df_inversion = pd.read_csv(url_inversion)

# %%
# El dataset que conecta ODS con Pps
url_ods = "https://github.com/GOLF-fisica/Dataket/raw/main/Semana4/alineacion_pp_ods.csv"

df_ods = pd.read_csv(url_ods, encoding="latin") # El encoding se escoje para que lea las letras con acento

# %%
# El dataset propio de la ubicación y población de los municipios de Guanajuato
url_gto = "https://raw.githubusercontent.com/GOLF-fisica/Dataket/main/Semana4/gto_poblacion_ubicacion.csv"

df_gto = pd.read_csv(url_gto)

# %% [markdown]
# ## Territorialización de la inversión pública asignada en 2021 (actualización al primer trimestre)

# %%
# Se convierten los strings del monto a float
df_inversion["Monto"] = df_inversion["Monto"].str.replace(",", "").astype(float)

# %%
# Número de proyectos
len(df_inversion["id_proceso_proyecto"].unique())
# Out:
# 439

# %%
# Número de Pp's
len(df_inversion["id_programa_presupuestario"].unique())
# Out:
# 59

# %%
# Número de categorías territoriales: 46 municipios + 2 categorías extra
len(df_inversion["Municipio"].unique())
# Out:
# 48

# %%
# Un df que se modificará para tener una linda gráfica
df_dummy = df_inversion.copy()

# Se añade un directorio base y se coloca el presupuesto en términos de mdp
df_dummy["Programas Presupuestarios"] = "Proyectos de inversión 2021 por Territorio y Programa"
df_dummy["Presupuesto (mdp)"] = round(df_dummy["Monto"].copy()/1_000_000, 2)

# Se hace el treemap
fig = px.treemap(df_dummy,
                 path=["Programas Presupuestarios", "Municipio", "id_programa_presupuestario"],
                 values="Presupuesto (mdp)", color_discrete_sequence=px.colors.sequential.Aggrnyl)

# Se aumenta el tamaño de la letra
fig.update_layout(font_size=13)

# Se guarda el html de la gráfica interactiva en el directorio actual
plotly.offline.plot(fig, filename='/work/treemap_inversion.html')

# Se muestra la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="6431d0f5-7009-4667-8505-84e7ae1d3fc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6431d0f5-7009-4667-8505-84e7ae1d3fc8")) {                    Plotly.newPlot(                        "6431d0f5-7009-4667-8505-84e7ae1d3fc8",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Presupuesto (mdp)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Abasolo/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Ac\u00e1mbaro/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cobertura Estatal/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Comonfort/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Doctor Mora/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Guanajuato/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Irapuato/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Le\u00f3n/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Ocampo/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Por Determinar/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Pur\u00edsima del Rinc\u00f3n/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/P\u00e9njamo/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Jos\u00e9 Iturbide/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Luis de la Paz/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Miguel de Allende/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Santa Cruz de Juventino Rosas/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Tarandacuao/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Victoria/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Xich\u00fa/E003","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Atarjea/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cobertura Estatal/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Salamanca/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Felipe/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Luis de la Paz/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/San Miguel de Allende/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Silao de la Victoria/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Xich\u00fa/E004","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cobertura Estatal/E005","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Silao de la Victoria/E007","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cobertura Estatal/E008","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Abasolo/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Ac\u00e1mbaro/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Apaseo el Alto/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Apaseo el Grande/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Atarjea/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Celaya/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Comonfort/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Coroneo/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cortazar/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/Cuer\u00e1maro/E009","Proyectos de inversi\u00f3n 2021 por Territorio y Programa/D ...

# %% [markdown]
# El archivo _GEO Json_ de los municipios de Guanajuato usado en el siguiente mapa coroplético fue hecho por Alberto Barradas y subido en Diciembre del 2016 al siguiente [enlace](http://datamx.io/sl/dataset/municipios-de-guanajuato).

# %%
# Se lee el archivo geojson de los municipios de Guanajuato
url_geojson = "http://datamx.io/sl/dataset/01a8a26c-8ce3-4b4c-a20c-033eeeab1669/resource/b1cd35b7-479e-4fa0-86e9-e897d3c617e6/download/gto.geojson"
with urlopen(url_geojson) as response:
    guanajuato = json.load(response)

# Se agrupa y prepara el dataset de las inversiones al primer trimestre del 2021
df_dummy = df_inversion.copy()

# Se agrupa el presupuesto para cada municipio y se le da el formato de millones
# de pesos, por eso se divide entre un millón
df_choropleth = df_dummy.groupby("Municipio", as_index=False).sum()
df_choropleth["Monto"] = round(df_choropleth["Monto"].copy()/1_000_000, 2)

# Se cambian los nombres de los municipios para que se ajusten a los nombres del geojson
df_choropleth["Municipio"] = df_choropleth["Municipio"].str.replace(" de la Victoria", "")
df_choropleth["Municipio"] = df_choropleth["Municipio"].str.replace("Jérecuaro", "Jerécuaro")


# Se hace el mapa
fig = px.choropleth(df_choropleth, geojson=guanajuato, locations='Municipio',
                    featureidkey="properties.mun_name",
                    color='Monto',
                    color_continuous_scale="Aggrnyl_r", 
                    range_color=(0, 1.5e3), 
                    labels={'Monto':'Presupuesto (mdp)'}
                    )

# Se centra el mapa en Guanajuato
fig.update_geos(fitbounds="locations", visible=False)

# Se configura el margen y el tamaño de la letra
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(font_size=15)

# Se guarda el html de la gráfica interactiva
plotly.offline.plot(fig, filename='/work/choropleth.html')

# Se uestra la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="d1e77164-0a5a-4acf-995a-1687db23c544" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1e77164-0a5a-4acf-995a-1687db23c544")) {                    Plotly.newPlot(                        "d1e77164-0a5a-4acf-995a-1687db23c544",                        [{"coloraxis":"coloraxis","featureidkey":"properties.mun_name","geo":"geo","geojson":{"crs":{"properties":{"name":"urn:ogc:def:crs:OGC:1.3:CRS84"},"type":"name"},"features":[{"geometry":{"coordinates":[[[-100.86051359054179,20.66102875813899],[-100.85195524900254,20.681397903669357],[-100.8842867614841,20.69794783441278],[-100.95687417676135,20.69740223230036],[-100.98001339647854,20.730502093787205],[-100.9670173963634,20.77978815127586],[-100.98888871363035,20.78851778507459],[-100.98857173801778,20.811433073796252],[-100.95402139624827,20.799247959952194],[-100.91376549345259,20.807795726380114],[-100.8896753468977,20.793428204086375],[-100.80377495589276,20.80815946112173],[-100.78634129720173,20.78215242709635],[-100.71819154050038,20.831256
# 64        2  Desarrollo Humano y Social                       E064
# 67        2  Desarrollo Humano y Social                       E064
# 71        2  Desarrollo Humano y Social                       E064
# 77        2  Desarrollo Humano y Social                       E064
# 78        3        Educación de Calidad                       E028
# 97        3        Educación de Calidad                       E047
# 98        3        Educación de Calidad                       E047
# 125       3        Educación de Calidad                       E047
# 128       2  Desarrollo Humano y Social                       E014
# 232       3        Educación de Calidad                       E047
# 237       2  Desarrollo Humano y Social                       E014
# 238       2  Desarrollo Humano y Social                       E014
# 328       2  Desarrollo Humano y Social                       E009
# 341       2  Desarrollo Humano y Social                       E048
# 503       2  Desarrollo Humano y Social                       E009
# 544       3        Educación de Calidad                       E047
# 548       2  Desarrollo Humano y Social                       E012
# 574       2  Desarrollo Humano y Social                       E019
#
#                    descripcion_programa_presupuestario id_componente  \
# 64                                 Prevención en salud      E064.C04
# 67                                 Prevención en salud      E064.C02
# 71                                 Prevención en salud      E064.C03
# 77                                 Prevención en salud      E064.C01
# 78   Desarrollo integral de los jóvenes guanajuatenses      E028.C01
# 97                    Práctica competitiva y deportiva      E047.C04
# 98                    Práctica competitiva y deportiva      E047.C07
# 125                   Práctica competitiva y deportiva      E047.C06
# 128  Certeza jurídica en los procesos conciliatorio...      E014.C01
# 232                   Práctica competitiva y deportiva      E047.C01
# 237  Certeza jurídica en los procesos conciliatorio...      E014.C02
# 238  Certeza jurídica en los procesos conciliatorio...      E014.C03
# 328             Atención integral para adultos mayores      E009.C03
# 341                Prevención de riesgos psicosociales      E048.C01
# 503             Atención integral para adultos mayores      E009.C02
# 544                   Práctica competitiva y deportiva      E047.C08
# 548       Servicios de salud con oportunidad y calidad      E012.C02
# 574                Cobertura de los servicios de salud      E019.C01
#
#                                 descripcion_componente       id_siglas  \
# 64   Acciones de enseñanza pertinente a la transici...          ISAPEG
# 67   Acciones de promoción de estilos de vida salud...          ISAPEG
# 71   Acciones de vigilancia epidemiológica de las e...          ISAPEG
# 77   Acciones preventivas en materia de salud reali...          ISAPEG
# 78   Acciones que fomenten la generación de herrami...  JUVENTUDES GTO
# 97   Apoyo a deportistas discapacitados del Estado ...            CODE
# 98         Apoyo al deporte popular o social otorgado.            CODE
# 125  Asesoría, atención y seguimiento a acciones de...            CODE
# 128  Atención brindada a quejas e inconformidades p...         CECAMED
# 232  Capacitación al personal en materia deportiva ...            CODE
# 237  Capacitaciones en el tema del modelo del pacie...         CECAMED
# 238  Capacitaciones en temas relacionados con la re...         CECAMED
# 328  Espacios para adultos mayores habilitados y op...             DIF
# 341  Eventos de difusión de la cultura de prevenció...             DIF
# 503                       Prótesis dentales entregadas             DIF
# 544  Servicios de medicina e investigación deportiv...            CODE
# 548  Servicios de salud oportunos y accesibles en l...          ISAPEG
# 574  Unidades médicas de primer nivel, ambulatoria,...          ISAPEG
#
#                                     descripcion_siglas  id_ods  \
# 64   Instituto de Salud Pública del Estado de Guana...       3
# 67   Instituto de Salud Pública del Estado de Guana...       3
# 71   Instituto de Salud Pública del Estado de Guana...       3
# 77   Instituto de Salud Pública del Estado de Guana...       3
# 78   Instituto para el Desarrollo y Atención a las ...       3
# 97        Comisión Estatal de Cultura Física y Deporte       3
# 98        Comisión Estatal de Cultura Física y Deporte       3
# 125       Comisión Estatal de Cultura Física y Deporte       3
# 128  Comisión Estatal de Conciliación y Arbitraje M...       3
# 232       Comisión Estatal de Cultura Física y Deporte       3
# 237  Comisión Estatal de Conciliación y Arbitraje M...       3
# 238  Comisión Estatal de Conciliación y Arbitraje M...       3
# 328  Sistema Estatal para el Desarrollo Integral de...       3
# 341  Sistema Estatal para el Desarrollo Integral de...       3
# 503  Sistema Estatal para el Desarrollo Integral de...       3
# 544       Comisión Estatal de Cultura Física y Deporte       3
# 548  Instituto de Salud Pública del Estado de Guana...       3
# 574  Instituto de Salud Pública del Estado de Guana...       3
#
#                                        descripcion_ods id_meta  \
# 64   Objetivo 3: Garantizar una vida sana y promove...     3.4
# 67   Objetivo 3: Garantizar una vida sana y promove...     3.4
# 71   Objetivo 3: Garantizar una vida sana y promove...     3.4
# 77   Objetivo 3: Garantizar una vida sana y promove...     3.4
# 78   Objetivo 3: Garantizar una vida sana y promove...     3.4
# 97   Objetivo 3: Garantizar una vida sana y promove...     3.c
# 98   Objetivo 3: Garantizar una vida sana y promove...     3.c
# 125  Objetivo 3: Garantizar una vida sana y promove...     3.c
# 128  Objetivo 3: Garantizar una vida sana y promove...     3.8
# 232  Objetivo 3: Garantizar una vida sana y promove...     3.c
# 237  Objetivo 3: Garantizar una vida sana y promove...     3.8
# 238  Objetivo 3: Garantizar una vida sana y promove...     3.c
# 328  Objetivo 3: Garantizar una vida sana y promove...     3.8
# 341  Objetivo 3: Garantizar una vida sana y promove...     3.d
# 503  Objetivo 3: Garantizar una vida sana y promove...     3.8
# 544  Objetivo 3: Garantizar una vida sana y promove...     3.c
# 548  Objetivo 3: Garantizar una vida sana y promove...     3.8
# 574  Objetivo 3: Garantizar una vida sana y promove...     3.8
#
#                                       descripcion_meta  id_tema_general  \
# 64   3.4 Reducir en un tercio la mortalidad prematu...                3
# 67   3.4 Reducir en un tercio la mortalidad prematu...                3
# 71   3.4 Reducir en un tercio la mortalidad prematu...                3
# 77   3.4 Reducir en un tercio la mortalidad prematu...                3
# 78   3.4 Reducir en un tercio la mortalidad prematu...                3
# 97   3.c Aumentar sustancialmente la financiación d...                3
# 98   3.c Aumentar sustancialmente la financiación d...                3
# 125  3.c Aumentar sustancialmente la financiación d...                3
# 128  3.8 Lograr la cobertura sanitaria universal, i...                3
# 232  3.c Aumentar sustancialmente la financiación d...                3
# 237  3.8 Lograr la cobertura sanitaria universal, i...                3
# 238  3.c Aumentar sustancialmente la financiación d...                3
# 328  3.8 Lograr la cobertura sanitaria universal, i...                3
# 341  3.d Reforzar la capacidad de todos los países,...                3
# 503  3.8 Lograr la cobertura sanitaria universal, i...                3
# 544  3.c Aumentar sustancialmente la financiación d...                3
# 548  3.8 Lograr la cobertura sanitaria universal, i...                3
# 574  3.8 Lograr la cobertura sanitaria universal, i...                3
#
#     descripcion_tema_general  id_tema_objetivo descripcion_tema_objetivo  \
# 64         Desarrollo social               3.4                 Vida sana
# 67         Desarrollo social               3.4                 Vida sana
# 71         Desarrollo social               3.4                 Vida sana
# 77         Desarrollo social               3.4                 Vida sana
# 78         Desarrollo social               3.4                 Vida sana
# 97         Desarrollo social               3.4                 Vida sana
# 98         Desarrollo social               3.4                 Vida sana
# 125        Desarrollo social               3.4                 Vida sana
# 128        Desarrollo social               3.4                 Vida sana
# 232        Desarrollo social               3.4                 Vida sana
# 237        Desarrollo social               3.4                 Vida sana
# 238        Desarrollo social               3.4                 Vida sana
# 328        Desarrollo social               3.4                 Vida sana
# 341        Desarrollo social               3.4                 Vida sana
# 503        Desarrollo social               3.4                 Vida sana
# 544        Desarrollo social               3.4                 Vida sana
# 548        Desarrollo social               3.4                 Vida sana
# 574        Desarrollo social               3.4                 Vida sana
#
#     id_meta_rubro_propuesta        descripcion_meta_rubro_propuesta
# 64                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 67                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 71                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 77                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 78                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 97                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 98                    3.4.1  VIH/SIDA, malaria y otras enfermedades
# 125                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 128                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 232                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 237                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 238                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 328                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 341                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 503                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 544                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 548                   3.4.1  VIH/SIDA, malaria y otras enfermedades
# 574                   3.4.1  VIH/SIDA, malaria y otras enfermedades

# %%
# Se define un dataframe que sirva para armar una bonita gráfica
df_dummy = df_inversion_ods_3.groupby("id_programa_presupuestario",
                                      as_index=False).sum().join(df_ods_3.set_index("id_programa_presupuestario")["id_siglas"],
                                                                 on="id_programa_presupuestario").drop_duplicates()

# Se ordenan las filas por monto aprobado y se divide entre un millón y se redondea 
# a dos lugares decimales para que todo quede en formato de millones de pesos
df_dummy = df_dummy.sort_values("Monto", ascending=False)
df_dummy["Monto"] = round(df_dummy["Monto"].copy()/1_000_000, 2)

# Se hace el barplot
fig = px.bar(df_dummy, x="Monto", y="id_programa_presupuestario",
             color="id_siglas", title="Programas presupuestarios asociados al ODS 3",
             color_discrete_sequence=colors,
             labels={'Monto':'Presupuesto (mdp)',
                     "id_programa_presupuestario": "Programa presupuestario",
                     "id_siglas": "Dependencia"})

# Se ordenan las barras por tamaño y se ajusta el tamaño de la letra
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.update_layout(font_size=18)

# Se guarda el html en el directorio de trabajo
plotly.offline.plot(fig, filename='/work/barchart_ods_3.html')

# Se muestra la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="daf5d718-0b90-4bf6-bda3-00299badeca9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daf5d718-0b90-4bf6-bda3-00299badeca9")) {                    Plotly.newPlot(                        "daf5d718-0b90-4bf6-bda3-00299badeca9",                        [{"alignmentgroup":"True","hovertemplate":"Dependencia=ISAPEG<br>Presupuesto (mdp)=%{x}<br>Programa presupuestario=%{y}<extra></extra>","legendgroup":"ISAPEG","marker":{"color":"#264653","pattern":{"shape":""}},"name":"ISAPEG","offsetgroup":"ISAPEG","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[440.8,55.5,18.7],"xaxis":"x","y":["E019","E064","E012"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Dependencia=CODE<br>Presupuesto (mdp)=%{x}<br>Programa presupuestario=%{y}<extra></extra>","legendgroup":"CODE","marker":{"color":"#2a9d8f","pattern":{"shape":""}},"name":"CODE","offsetgroup":"CODE","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[93.36],"xaxis":"x","y":["E047"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Dependencia=DIF<br>Presupuesto (mdp)=%{x}<br>Programa presupuestario=%{y}<extra></extra>","legendgroup":"DIF","marker":{"color":"#e9C46a","pattern":{"shape":""}},"name":"DIF","offsetgroup":"DIF","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[80.0],"xaxis":"x","y":["E009"],"yaxis":"y"}],                        {"barmode":"relative","font":{"size":18},"legend":{"title":{"text":"Dependencia"},"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786 ...

# %%
# Un df que se modificará para tener una linda gráfica
df_dummy = df_inversion_ods_3.copy()

# Se añade un directorio base y se coloca el presupuesto en términos de mdp
df_dummy["Programas Presupuestarios"] = "Proyectos de inversión 2021 asociados al ODS 3 por Territorio y Programa"
df_dummy["Presupuesto (mdp)"] = round(df_dummy["Monto"].copy()/1_000_000, 2)

# Se hace el treemap
fig = px.treemap(df_dummy,
                 path=["Programas Presupuestarios", "Municipio", "id_programa_presupuestario"],
                 values="Presupuesto (mdp)", color_discrete_sequence=px.colors.sequential.Aggrnyl)

# Se ajusta el tamaño de la letra
fig.update_layout(font_size=13)

# Se guarda el html
plotly.offline.plot(fig, filename='/work/treemap_inversion_ods_3.html')

# Se muestra la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="50001132-8311-49a2-8209-597374dee1ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50001132-8311-49a2-8209-597374dee1ad")) {                    Plotly.newPlot(                        "50001132-8311-49a2-8209-597374dee1ad",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Presupuesto (mdp)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Abasolo/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Ac\u00e1mbaro/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Apaseo el Alto/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Apaseo el Grande/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Atarjea/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Celaya/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Comonfort/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Coroneo/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Cortazar/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Cuer\u00e1maro/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Doctor Mora/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Dolores Hidalgo Cuna de la Independencia Nacional/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Guanajuato/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Huan\u00edmaro/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Irapuato/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Jaral del Progreso/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/J\u00e9recuaro/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Le\u00f3n/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Manuel Doblado/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Morole\u00f3n/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Ocampo/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Pueblo Nuevo/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Pur\u00edsima del Rinc\u00f3n/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/P\u00e9njamo/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Romita/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Salamanca/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/Salvatierra/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/San Diego de la Uni\u00f3n/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/San Felipe/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/San Francisco del Rinc\u00f3n/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/San Jos\u00e9 Iturbide/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y Programa/San Luis de la Paz/E009","Proyectos de inversi\u00f3n 2021 asociados al ODS 3 por Territorio y ...

# %%
# Se agrupa y prepara el dataset de las inversiones al primer trimestre del 2021
df_dummy = df_inversion_ods_3.copy()
df_choropleth = df_dummy.groupby("Municipio", as_index=False).sum()
df_choropleth["Monto"] = round(df_choropleth["Monto"].copy()/1_000_000, 2)

# Se cambian los nombres de los municipios para que se ajusten a los nombres del geojson
state_code":11},"type":"Feature"},{"geometry":{"coordinates":[[[-101.78576540361712,21.048769992699185],[-101.82094969661176,21.0358574093719],[-101.83362872111434,21.053316676969356],[-101.8694469653341,21.03822168519239],[-101.85645096521897,20.996937792019235],[-101.88751457525028,20.902184891828867],[-101.90304638026592,20.826164330831606],[-101.99623721035985,20.83507583200114],[-102.05392677184656,20.815434155954],[-102.06755672318683,20.771604119589554],[-102.07389623543811,20.776514538601337],[-102.08752618677838,20.778878814421827],[-102.0802357476894,20.827983004539675],[-102.05487769868425,20.846351608991167],[-101.93727974642287,20.95565389884608],[-101.90875194129208,20.99839273098569],[-101.88688062402514,21.061136973914053],[-101.87166579462206,21.095328039625738],[-101.81777994048612,21.10678568398657],[-101.80890462333431,21.051861738002902],[-101.78576540361712,2 ...

# %% [markdown]
# ## Propuesta para dar seguimiento al ODS 3

# %%
# A continuación se hará un ejemplo de juguete sobre nuestra propuesta

# Se corrige el tab de los nombres de los municipios
df_gto["Municipio"] = df_gto["Municipio"].str.replace("\t","")

# %%
# Se crea la función para implementar un k-means, con el número de clusters que el
# usuario indique y luego coloque los centroides resultantes en una gráfica del
# estado de Guanajuato

def grafica_kmeans(n_clusters):
    # Se prepara el algoritmo
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=0, max_iter=10_000)

    # Se preparan los arrays
    X = df_gto[["Latitud", "Longitud"]]
    Y = df_gto["Poblacion"]

    # Se hace el clustering usado en X las coordenadas del input y Y es el peso de la muestra
    # en este caso, el peso es la población por cada municipio
    wt_kmeansclus = kmeans.fit(X,sample_weight = Y)
    
    # Los centroides del k-means
    centroides = wt_kmeansclus.cluster_centers_

    # Se hace la gráfica

    # Se prepara el dataset para la gráfica, usando las categorías necesarias
    df_dummy = df_gto[["Municipio", "Longitud", "Latitud", "Poblacion"]].copy()
    df_dummy["Tipo"] = "Municipio"
    df_dummy["Fondo"] = 1
    df_dummy["Municipio"] = df_dummy["Municipio"].str.replace(" de la Victoria", "")
    
    # Se añaden al dataset de la gráffica la ubicación de los centroides del kmeans
    for i in range(len(centroides)):
        df_dummy = df_dummy.append({"Municipio": "Centroide "+str(i+1),
                                    "Longitud": centroides[i][1],
                                    "Latitud": centroides[i][0],
                                    "Tipo": "Centroide"}, ignore_index=True)

    # Se hace el scatter geo con los centroides
    fig = px.scatter_geo(df_dummy[df_dummy["Tipo"]=="Centroide"], # Se van a colocar sólo los centroides
                        lon="Longitud", lat="Latitud",
                        color="Tipo", hover_name="Municipio", fitbounds="locations",
                        color_discrete_sequence=[colors[1],colors[2]], basemap_visible=False)

    # Se hace un mapa coroplético sobre una variable de un solo valor para resaltar
    # la forma del estado. El argumento showscale es para no ostrar la barra de colores
    fig.add_trace(go.Choropleth(geojson=guanajuato, featureidkey="properties.mun_name",
                                locations=df_dummy["Municipio"], z=df_dummy["Fondo"],
                                text=df_dummy["Municipio"],
                                # El hovertemplate es para imprimir sólo los nombres del
                                # municipio en negritas y el segundo string que se muestra
                                # es para que no se imprima qué numero de trace es lo que se
                                # muestra
                                hovertemplate="<b>%{text}</b><br><br>"+"<extra></extra>",
                                showscale=False, colorscale="Viridis",
                                zmin=0, zmax=1.005))

    # Se configura el margen
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

    # Se configura el tamaño de la letra y se quitan las acotaciones
    fig.update_layout(font_size=15)
    fig.update_layout(showlegend=False)

    # Se guarda el html de la gráfica
    plotly.offline.plot(fig, filename='/work/kmeans_'+str(n_clusters)+'.html')

    # Se muestra la gráfica
    fig.show()

# %%
# Gráfica para 15 centroides
grafica_kmeans(15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="13e9e822-c332-471e-a927-2668bee86a1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13e9e822-c332-471e-a927-2668bee86a1a")) {                    Plotly.newPlot(                        "13e9e822-c332-471e-a927-2668bee86a1a",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Tipo=Centroide<br>Latitud=%{lat}<br>Longitud=%{lon}<extra></extra>","hovertext":["Centroide 1","Centroide 2","Centroide 3","Centroide 4","Centroide 5","Centroide 6","Centroide 7","Centroide 8","Centroide 9","Centroide 10","Centroide 11","Centroide 12","Centroide 13","Centroide 14","Centroide 15"],"lat":[20.45161605774972,20.944381764344577,20.13828200254348,21.220791543713617,20.6744079110231,21.1219138,21.510142943108992,20.55597751424647,21.174973281727084,20.277723534677225,20.9693571272928,20.930665358250927,20.136179854241767,21.2934436,20.545309477005837],"legendgroup":"Centroide","lon":[-101.63972528730304,-100.62347969748801,-100.78337893653027,-100.91965178128295,-101.34244316752853,-101.6660114,-101.26311242473388,-101.08969930737781,-100.1779207777155,-101.1624613036931,-101.36898979787678,-101.88716562741831,-100.48940140775339,-100.5168806,-100.77408555555692],"marker":{"color":"#2a9d8f","symbol":"circle"},"mode":"markers","name":"Centroide","showlegend":true,"type":"scattergeo"},{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"featureidkey":"properties.mun_name","geojson":{"crs":{"properties":{"name":"urn:ogc:def:crs:OGC:1.3:CRS84"},"type":"name"},"features":[{"geometry":{"coordinates":[[[-100.86051359054179,20.66102875813899],[-100.85195524900254,20.681397903669357],[-100.8842867614841,20.69794783441278],[-100.95687417676135,20.69740223230036],[-100.98001339647854,20.730502093787205],[-100.9670173963634,20.77978815127586],[-100.98888871363035,20.78851778507459],[-100.98857173801778,20.811433073796252],[-100.95402139624827,20.799247959952194],[-100.91376549345259,20.807795726380114],[-100.8896753468977,20.793428204086375],[-100.80377495589276,20.80815946112173],[-100.78634129720173,20.78215242709635],[-100.71819154050038,20.831256617214198],[-100.67761866209216,20.79997542943542],[-100.63229114949546,20.792336999861533],[-100.61549144202954,20.76305635316163],[-100.61897817376774,20.715952704122657],[-100.63514393000852,20.66684851400481],[-100.66684149126496,20.688672598501633],[-100.7226291990763,20.679761097332097],[-100.74957212614426,20.65248099171107],[-100.80948051691892,20.688308863760017],[-100.82501232193458,20.66502984029674],[-100.86051359054179,20.66102875813899]]],"type":"Polygon"},"properties":{"id":null,"mun_code":9,"mun_name":"Comonfort","state_code":11},"type":"Feature"},{"geometry":{"coordinates":[[[
state_code":11},"type":"Feature"},{"geometry":{"coordinates":[[[-100.63514393000852,20.66684851400481],[-100.67603378402933,20.618108058628575],[-100.69822207690883,20.621199803932292],[-100.71311993069936,20.56773079691508],[-100.75781349207094,20.537358945990334],[-100.74893817491913,20.48516301056877],[-100.69283349149524,20.46843121245454],[-100.69093163781986,20.423873706606862],[-100.73784402847939,20.37386017963498],[-100.78222061423838 ...

# %% [markdown]
# ## Presupuesto de inversión territorializado per cápita

# %%
df_choropleth_poblacion
# Out:
#                                             Municipio   ciclo  id_eje  \
# 0                                             Abasolo  109134     185
# 1                                            Acámbaro  129344     208
# 2                                      Apaseo el Alto   99029     168
# 3                                    Apaseo el Grande  103071     171
# 4                                             Atarjea   72756     105
# 5                                              Celaya  194016     333
# 6                                   Cobertura Estatal  323360     580
# 7                                           Comonfort  135407     233
# 8                                             Coroneo   76798     120
# 9                                            Cortazar  131365     226
# 10                                          Cuerámaro   90945     148
# 11                                        Doctor Mora   99029     163
# 12  Dolores Hidalgo Cuna de la Independencia Nacional  167743     296
# 13                                         Guanajuato  191995     351
# 14                                          Huanímaro   92966     154
# 15                                           Irapuato  206142     349
# 16                                 Jaral del Progreso  109134     182
# 17                                          Jerécuaro   78819     125
# 18                                               León  256667     444
# 19                                     Manuel Doblado  103071     176
# 20                                           Moroleón   99029     160
# 21                                             Ocampo  103071     182
# 22                                     Por Determinar  113176     174
# 23                                       Pueblo Nuevo   74777     117
# 24                                Purísima del Rincón  127323     225
# 25                                            Pénjamo  143491     237
# 26                                             Romita   97008     156
# 27                                          Salamanca  173806     288
# 28                                        Salvatierra  137428     235
# 29                              San Diego de la Unión  103071     179
# 30                                         San Felipe  119239     208
# 31                           San Francisco del Rincón  123281     211
# 32                                  San José Iturbide   99029     164
# 33                                 San Luis de la Paz  135407     233
# 34                              San Miguel de Allende  175827     301
# 35                                     Santa Catarina   74777     120
# 36                      Santa Cruz de Juventino Rosas  105092     181
# 37                                 Santiago Maravatío   68714     107
# 38                                              Silao  175827     309
# 39                                        Tarandacuao   76798     121
# 40                                           Tarimoro   86903     140
# 41                                      Tierra Blanca   88924     143
# 42                                          Uriangato   92966     147
# 43                                  Valle de Santiago  129344     218
# 44                                           Victoria   99029     157
# 45                                          Villagrán   97008     153
# 46                                              Xichú   92966     148
# 47                                            Yuriria  113176     193
#
#            Monto  Poblacion  Monto per capita
# 0   1.356057e+08    92040.0              0.00
# 1   2.136103e+08   108697.0              0.00
# 2   6.434133e+07    63392.0              0.00
# 3   9.148345e+07   117883.0              0.00
# 4   7.117870e+07     5296.0              0.01
# 5   4.005625e+08   521169.0              0.00
# 6   1.914379e+09        NaN               NaN
# 7   9.947362e+07    82216.0              0.00
# 8   3.010314e+07    11083.0              0.00
# 9   1.236020e+08    97928.0              0.00
# 10  5.274372e+07    30857.0              0.00
# 11  4.684470e+07    27390.0              0.00
# 12  1.901255e+08   163038.0              0.00
# 13  3.488294e+08   194500.0              0.00
# 14  5.355452e+07    21128.0              0.00
# 15  8.387199e+08   592953.0              0.00
# 16  1.054550e+08    38782.0              0.00
# 17  4.215532e+07    49517.0              0.00
# 18  1.245070e+09  1721215.0              0.00
# 19  7.736806e+07    41240.0              0.00
# 20  7.374979e+07    47261.0              0.00
# 21  3.888055e+07    26383.0              0.00
# 22  5.452791e+09        NaN               NaN
# 23  1.837710e+07    12403.0              0.00
# 24  1.243512e+08    83842.0              0.00
# 25  2.203739e+08   154960.0              0.00
# 26  1.165070e+08    65766.0              0.00
# 27  1.939217e+08   273417.0              0.00
# 28  1.795419e+08    94126.0              0.00
# 29  6.509181e+07    41054.0              0.00
# 30  1.333423e+08   119793.0              0.00
# 31  9.905235e+07   130871.0              0.00
# 32  6.689134e+07    89558.0              0.00
# 33  7.806584e+07   128536.0              0.00
# 34  5.842624e+08   174615.0              0.00
# 35  2.621707e+07     5723.0              0.00
# 36  9.062512e+07    82340.0              0.00
# 37  2.627968e+07     6714.0              0.00
# 38  2.467335e+08   203556.0              0.00
# 39  2.716432e+07    11304.0              0.00
# 40  7.659204e+07    35905.0              0.00
# 41  3.074833e+07    20007.0              0.00
# 42  5.303316e+07    61494.0              0.00
# 43  2.207297e+08   150054.0              0.00
# 44  8.887060e+07    21253.0              0.00
# 45  5.432221e+07    65791.0              0.00
# 46  6.284807e+07    11143.0              0.01
# 47  1.254106e+08    68741.0              0.00

# %%
# Se agrupa y prepara el dataset de las inversiones al primer trimestre del 2021 per capita
df_dummy = df_inversion.copy()

# Se agrupa el presupuesto para cada municipio y se le da el formato de millones
# de pesos, por eso se divide entre un millón
df_choropleth = df_dummy.groupby("Municipio", as_index=False).sum()

# Se cambian los nombres de los municipios para que se ajusten a los nombres del geojson
df_choropleth["Municipio"] = df_choropleth["Municipio"].str.replace("Jérecuaro", "Jerécuaro")

# Se hace el cálculo per cápita
df_choropleth_poblacion = df_choropleth.join(df_gto.set_index("Municipio")["Poblacion"], on="Municipio")
df_choropleth_poblacion["Monto per capita"] = round(df_choropleth_poblacion["Monto"].copy()/(df_choropleth_poblacion["Poblacion"].copy()), 2)

# Se cambian los nombres de los municipios para que se ajusten a los nombres del geojson
df_choropleth_poblacion["Municipio"] = df_choropleth_poblacion["Municipio"].str.replace(" de la Victoria", "")

# Se hace el mapa
fig = px.choropleth(df_choropleth_poblacion, geojson=guanajuato, locations='Municipio',
                    featureidkey="properties.mun_name",
                    color='Monto per capita',
                    color_continuous_scale="tempo", 
                    range_color=(0, 14e3), 
                    labels={'Monto per capita':'Presupuesto per cápita (MXN)'}
                    )

# Se centra el mapa en Guanajuato
fig.update_geos(fitbounds="locations", visible=False)

# Se configura el margen y el tamaño de la letra
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(font_size=15)

# Se guarda el html de la gráfica interactiva
plotly.offline.plot(fig, filename='/work/choropleth_per_capita.html')

# Se uestra la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="af8c8d0d-12bf-48fd-bbac-294cfe0b7f0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af8c8d0d-12bf-48fd-bbac-294cfe0b7f0c")) {                    Plotly.newPlot(                        "af8c8d0d-12bf-48fd-bbac-294cfe0b7f0c",                        [{"coloraxis":"coloraxis","featureidkey":"properties.mun_name","geo":"geo","geojson":{"crs":{"properties":{"name":"urn:ogc:def:crs:OGC:1.3:CRS84